# %%
import os
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from pathlib import Path
from collections import Counter
from sicar import Sicar
import random
from difflib import SequenceMatcher

# %%
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
data_dir = Path("../dataset/")

images = list(data_dir.glob("*.png"))

num_images = len(images)

print("Number of images: ", num_images)
# Out:
# Number of images:  14

# %%
plt.figure(figsize=(12,6))
random_images = random.sample(range(num_images), 9)
print("Shape of images: ", mpimg.imread(str(images[random_images[0]]),0).shape)

for i in range(9):
    plt.subplot(3,3,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(mpimg.imread(str(images[random_images[i]]),0))
    plt.xlabel(str(images[random_images[i]]).split('\\')[-1].split('/')[-1])
plt.show()
# Out:
# Shape of images:  (50, 150, 4)

# %%
car = Sicar()

# %%
for image in images:
    _, filename = car.process_captcha(image.stem, folder="../dataset")
    captcha = car.get_captcha_ocr(filename, folder="../dataset")
    
    print('Original: {:>8} - Detected: {:>8} - Similarity: {:>8.1f} %'.format(image.stem, captcha, similar(image.stem, captcha)*100))
# Out:
# Original:    qMT5V - Detected:    QMTSv - Similarity:     40.0 %
# Original:    f7QeJ - Detected:    f7Qej - Similarity:     80.0 %
# Original:    tA268 - Detected:    tA268 - Similarity:    100.0 %
# Original:    Rs7ov - Detected:    RS76V - Similarity:     40.0 %
# Original:    sgffr - Detected:    sotfr - Similarity:     60.0 %
# Original:    NjaDM - Detected:    NadDM - Similarity:     80.0 %
# Original:    AbgBy - Detected:    AbgBy - Similarity:    100.0 %
# Original:    n3aoD - Detected:    n3a0D - Similarity:     80.0 %
# Original:    VfFnh - Detected:    VfFnh - Similarity:    100.0 %
# Original:    Ca7Qk - Detected:    Ca7Qk - Similarity:    100.0 %
# Original:    VwcEp - Detected:    Vwetp - Similarity:     60.0 %
# Original:    DYDfJ - Detected:    DYDrj - Similarity:     60.0 %
# Original:    sWtZP - Detected:   sWEtZP - Similarity:     90.9 %
# Original:    ZS7pc - Detected:    ZS7pc - Similarity:    100.0 %
